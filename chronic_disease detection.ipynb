# %%
# import necessary libraries like numpy, pandas, pyplot and seaborn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading dataset
chronic_df = pd.read_csv('/content/kidney_disease.csv')
chronic_df.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %% [markdown]
# ## **`Dataset Description`**
# - age		-	age
# - bp		-	blood pressure
# - sg		-	specific gravity
# - al		-   	albumin
# - su		-	sugar
# - rbc		-	red blood cells
# - pc		-	pus cell
# - pcc		-	pus cell clumps
# - ba		-	bacteria
# - 	bgr		-	blood glucose random
# -			bu		-	blood urea
# -			sc		-	serum creatinine
# -			sod		-	sodium
# -			pot		-	potassium
# -			hemo		-	hemoglobin
# -			pcv		-	packed cell volume
# -			wc		-	white blood cell count
# -			rc		-	red blood cell count
# -			htn		-	hypertension
# -			dm		-	diabetes mellitus
# -			cad		-	coronary artery disease
# -			appet		-	appetite
# -			pe		-	pedal edema
# -			ane		-	anemia
# -			class		-	class
# - ##################################################
# %
# - Number of Attributes: 24 + class = 25 ( 11  numeric ,14  nominal)
# %
# <h3>Attribute Information :</h3>
# - 1.Age(numerical)
#   	  	age in years
# - 	2.Blood Pressure(numerical)
# 	       	bp in mm/Hg
# -	3.Specific Gravity(nominal)
# 	  	sg - (1.005,1.010,1.015,1.020,1.025)
# - 	4.Albumin(nominal)
# 		  al - (0,1,2,3,4,5)
# -	5.Sugar(nominal)
# 		  su - (0,1,2,3,4,5)
# - 	6.Red Blood Cells(nominal)
# 		  rbc - (normal,abnormal)
# - 	7.Pus Cell (nominal)
# 		  pc - (normal,abnormal)
# - 	8.Pus Cell clumps(nominal)
# 		  pcc - (present,notpresent)
# - 	9.Bacteria(nominal)
# 		  ba  - (present,notpresent)
# - 	10.Blood Glucose Random(numerical)
# 		  bgr in mgs/dl
# - 	11.Blood Urea(numerical)
# 		  bu in mgs/dl
# - 	12.Serum Creatinine(numerical)
# 		  sc in mgs/dl
# - 	13.Sodium(numerical)
# 		  sod in mEq/L
# - 	14.Potassium(numerical)
# 		  pot in mEq/L
# - 	15.Hemoglobin(numerical)
# 		  hemo in gms
# - 	16.Packed  Cell Volume(numerical)
# - 	17.White Blood Cell Count(numerical)
# 		  wc in cells/cumm
# - 	18.Red Blood Cell Count(numerical)
# 		  rc in millions/cmm
# - 	19.Hypertension(nominal)
# 		  htn - (yes,no)
# - 	20.Diabetes Mellitus(nominal)
# 		  dm - (yes,no)
# - 	21.Coronary Artery Disease(nominal)
# 		  cad - (yes,no)
# - 	22.Appetite(nominal)
# 	    appet - (good,poor)
# - 	23.Pedal Edema(nominal)
# 		  pe - (yes,no)
# - 	24.Anemia(nominal)
# 		  ane - (yes,no)
# - 	25.Class (nominal)
# 		  class - (ckd,notckd)

# %%
# checking info of columns and null values

chronic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
#  17  wc              295 non-null    object
#  18  rc              270 non-null    object
#  19  htn             398 non-null    object
#  20  dm              398 non-null    object
#  21  cad             398 non-null    object
#  22  appet           399 non-null    object
#  23  pe              399 non-null    object
#  24  ane             399 non-null    object
#  25  classification  400 non-null    object
# dtypes: float64(11), int64(1), object(14)
# memory usage: 81.4+ KB

# %% [markdown]
# ## **`Data Cleaning`**

# %%
# drop id column
chronic_df = chronic_df.drop("id",axis=1)

# %%
# rename column names to make it more user-friendly

chronic_df.columns = ['age', 'blood_pressure', 'specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell',
              'pus_cell_clumps', 'bacteria', 'blood_glucose_random', 'blood_urea', 'serum_creatinine', 'sodium',
              'potassium', 'haemoglobin', 'packed_cell_volume', 'white_blood_cell_count', 'red_blood_cell_count',
              'hypertension', 'diabetes_mellitus', 'coronary_artery_disease', 'appetite', 'peda_edema',
              'aanemia', 'class']

# %%
chronic_df.head()
# Out:
#     age  blood_pressure  specific_gravity  albumin  sugar red_blood_cells  \
# 0  48.0            80.0             1.020      1.0    0.0             NaN
# 1   7.0            50.0             1.020      4.0    0.0             NaN
# 2  62.0            80.0             1.010      2.0    3.0          normal
# 3  48.0            70.0             1.005      4.0    0.0          normal
# 4  51.0            80.0             1.010      2.0    0.0          normal
#
#    pus_cell pus_cell_clumps    bacteria  blood_glucose_random  ...  \
# 0    normal      notpresent  notpresent                 121.0  ...
# 1    normal      notpresent  notpresent                   NaN  ...
# 2    normal      notpresent  notpresent                 423.0  ...
# 3  abnormal         present  notpresent                 117.0  ...
# 4    normal      notpresent  notpresent                 106.0  ...
#
#    packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# 0                  44                    7800                   5.2
# 1                  38                    6000                   NaN
# 2                  31                    7500                   NaN
# 3                  32                    6700                   3.9
# 4                  35                    7300                   4.6
#
#    hypertension  diabetes_mellitus coronary_artery_disease appetite  \
# 0           yes                yes                      no     good
# 1            no                 no                      no     good
# 2            no                yes                      no     poor
# 3           yes                 no                      no     poor
# 4            no                 no                      no     good
#
#   peda_edema aanemia class
# 0         no      no   ckd
# 1         no      no   ckd
# 2         no     yes   ckd
# 3        yes     yes   ckd
# 4         no      no   ckd
#
# [5 rows x 25 columns]

# %% [markdown]
# ### According to the data description
# - Cols(pcv, wc and rc) needs to convert back in numerical since it is object right now
# - Cols(sg, al and su) should be nominal , convert from float to object

# %%
# Categorical cols like specific_gravity, albumin and sugar which is float type right now
# converting back to nominal data type categorical
chronic_df["specific_gravity"]=chronic_df["specific_gravity"].astype("str")
chronic_df["albumin"]=chronic_df["albumin"].astype("str")
chronic_df["sugar"]=chronic_df["sugar"].astype("str")

# %%
chronic_df["packed_cell_volume"]=pd.to_numeric(chronic_df["packed_cell_volume"],errors="coerce")
chronic_df["white_blood_cell_count"]=pd.to_numeric(chronic_df["white_blood_cell_count"],errors="coerce")
chronic_df["red_blood_cell_count"]=pd.to_numeric(chronic_df["red_blood_cell_count"],errors="coerce")

# %%
# Extracting categorical and numerical columns

cat_cols =chronic_df.select_dtypes(include=("object")).columns
num_cols = chronic_df.select_dtypes(include=("int","float")).columns

# %%
# by looping & looking at unique values in categorical columns
for column in cat_cols:
  print(f"{column} has {chronic_df[column].unique()} values")
# Out:
# specific_gravity has ['1.02' '1.01' '1.005' '1.015' 'nan' '1.025'] values
# albumin has ['1.0' '4.0' '2.0' '3.0' '0.0' 'nan' '5.0'] values
# sugar has ['0.0' '3.0' '4.0' '1.0' 'nan' '2.0' '5.0'] values
# red_blood_cells has [nan 'normal' 'abnormal'] values
# pus_cell has ['normal' 'abnormal' nan] values
# pus_cell_clumps has ['notpresent' 'present' nan] values
# bacteria has ['notpresent' 'present' nan] values
# hypertension has ['yes' 'no' nan] values
# diabetes_mellitus has ['yes' 'no' ' yes' '\tno' '\tyes' nan] values
# coronary_artery_disease has ['no' 'yes' '\tno' nan] values
# appetite has ['good' 'poor' nan] values
# peda_edema has ['no' 'yes' nan] values
# aanemia has ['no' 'yes' nan] values
# class has ['ckd' 'ckd\t' 'notckd'] values

# %%
# replace incorrect values like '\tno', '\tyes', ' yes', '\tno', 'ckd\t', 'notckd'  in categorical cols
chronic_df=chronic_df.replace("\tno","no")
chronic_df=chronic_df.replace("\tyes","yes")
chronic_df=chronic_df.replace("ckd\t","ckd")
chronic_df=chronic_df.replace(" yes","yes")

# %%
# Converting target col class into 0(chronic kidney) and 1(not a chronic kidney)

chronic_df=chronic_df.replace("ckd",0)
chronic_df=chronic_df.replace("notckd",1)



# coverting target col into numeric to check correlation

# %%
# let's see the cols in numerical col list

print(cat_cols)
# Out:
# Index(['specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell',
#        'pus_cell_clumps', 'bacteria', 'hypertension', 'diabetes_mellitus',
#        'coronary_artery_disease', 'appetite', 'peda_edema', 'aanemia',
#        'class'],
#       dtype='object')

# %% [markdown]
# ## **`EDA`**

# %%
# checking numerical features distribution
import matplotlib.pyplot as plt
import warnings
warnings .filterwarnings("ignore")

plt.figure(figsize=(20,12))

# looping over num cols and checking its distribution
for column in num_cols:
  sns.distplot(chronic_df[column],kde=True,hist=False)
  plt.show()

# %%
# let's see the cols in cat col list
print(cat_cols)
# Out:
# Index(['specific_gravity', 'albumin', 'sugar', 'red_blood_cells', 'pus_cell',
#        'pus_cell_clumps', 'bacteria', 'hypertension', 'diabetes_mellitus',
#        'coronary_artery_disease', 'appetite', 'peda_edema', 'aanemia',
#        'class'],
#       dtype='object')

# %%
# checking cat features distribution

# create the figure and axes

fig, axes = plt.subplots(3, 5, figsize=(16,8))


axes = axes.flatten()  # flattening the array makes indexing easier

# loop over cat cols and plot countplot
for column,ax in zip(cat_cols,axes):
  sns.countplot(chronic_df,x=column,ax=ax)
  plt.xlabel(column)
  fig.tight_layout()

# %%
# correlated heatmap of data

plt.figure(figsize = (15, 8))
sns.heatmap(chronic_df.corr(),annot=True)

plt.show()

# %%
#chi2 test
from scipy.stats import chi2_contingency
def chi2_test(var1,var2):
  contigancy_table=pd.crosstab(chronic_df[var1],chronic_df[var2])
  b=chi2_contingency(contigancy_table)
  p_value=b[1]
  alpha=0.05
  if p_value<alpha:
    print(f"reject Ho:there is a realtion between {var1} and {var2}")
  else:
    print(f"retain Ho:there is no realtion between {var1} and {var2}")

# %%
#looping all the categrical_varibles
for col1 in cat_cols:
  for col2 in cat_cols:
    if col1!=col2:
      chi2_test(col1,col2)
# Out:
# reject Ho:there is a realtion between specific_gravity and albumin
# reject Ho:there is a realtion between specific_gravity and sugar
# reject Ho:there is a realtion between specific_gravity and red_blood_cells
# reject Ho:there is a realtion between specific_gravity and pus_cell
# reject Ho:there is a realtion between specific_gravity and pus_cell_clumps
# reject Ho:there is a realtion between specific_gravity and bacteria
# reject Ho:there is a realtion between specific_gravity and hypertension
# reject Ho:there is a realtion between specific_gravity and diabetes_mellitus
# reject Ho:there is a realtion between specific_gravity and coronary_artery_disease
# reject Ho:there is a realtion between specific_gravity and appetite
# reject Ho:there is a realtion between specific_gravity and peda_edema
# reject Ho:there is a realtion between specific_gravity and aanemia
# reject Ho:there is a realtion between specific_gravity and class
# reject Ho:there is a realtion between albumin and specific_gravity
# reject Ho:there is a realtion between albumin and sugar
# reject Ho:there is a realtion between albumin and red_blood_cells
# reject Ho:there is a realtion between albumin and pus_cell
# reject Ho:there is a realtion between albumin and pus_cell_clumps
# reject Ho:there is a realtion between albumin and bacteria
# reject Ho:there is a realtion between albumin and hypertension
# reject Ho:there is a realtion between albumin and diabetes_mellitus
# reject Ho:there is a realtion between albumin and coronary_artery_disease
# reject Ho:there is a realtion between albumin and appetite
# reject Ho:there is a realtion between albumin and peda_edema
# reject Ho:there is a realtion between albumin and aanemia
# reject Ho:there is a realtion between albumin and class
# reject Ho:there is a realtion between sugar and specific_gravity
# reject Ho:there is a realtion between sugar and albumin
# reject Ho:there is a realtion between sugar and red_blood_cells
# reject Ho:there is a realtion between sugar and pus_cell
# reject Ho:there is a realtion between sugar and pus_cell_clumps
# reject Ho:there is a realtion between sugar and bacteria
# reject Ho:there is a realtion between sugar and hypertension
# reject Ho:there is a realtion between sugar and diabetes_mellitus
# reject Ho:there is a realtion between sugar and coronary_artery_disease
# reject Ho:there is a realtion between sugar and appetite
# reject Ho:there is a realtion between sugar and peda_edema
# reject Ho:there is a realtion between sugar and aanemia
# reject Ho:there is a realtion between sugar and class
# reject Ho:there is a realtion between red_blood_cells and specific_gravity
# reject Ho:there is a realtion between red_blood_cells and albumin
# reject Ho:there is a realtion between red_blood_cells and sugar
# reject Ho:there is a realtion between red_blood_cells and pus_cell
# retain Ho:there is no realtion between red_blood_cells and pus_cell_clumps
# reject Ho:there is a realtion between red_blood_cells and bacteria
# reject Ho:there is a realtion between red_blood_cells and hypertension
# reject Ho:there is a realtion between red_blood_cells and diabetes_mellitus
# reject Ho:there is a realtion between red_blood_cells and coronary_artery_disease
# reject Ho:there is a realtion between red_blood_cells and appetite
# reject Ho:there is a realtion between red_blood_cells and peda_edema
# reject Ho:there is a realtion between red_blood_cells and aanemia
# reject Ho:there is a realtion between red_blood_cells and class
# reject Ho:there is a realtion between pus_cell and specific_gravity
# reject Ho:there is a realtion between pus_cell and albumin
# reject Ho:there is a realtion between pus_cell and sugar
# reject Ho:there is a realtion between pus_cell and red_blood_cells
# reject Ho:there is a realtion between pus_cell and pus_cell_clumps
# reject Ho:there is a realtion between pus_cell and bacteria
# reject Ho:there is a realtion between pus_cell and hypertension
# reject Ho:there is a realtion between pus_cell and diabetes_mellitus
# reject Ho:there is a realtion between pus_cell and coronary_artery_disease
# reject Ho:there is a realtion between pus_cell and appetite
# reject Ho:there is a realtion between pus_cell and peda_edema
# reject Ho:there is a realtion between pus_cell and aanemia
# reject Ho:there is a realtion between pus_cell and class
# reject Ho:there is a realtion between pus_cell_clumps and specific_gravity
# reject Ho:there is a realtion between pus_cell_clumps and albumin
# reject Ho:there is a realtion between pus_cell_clumps and sugar
# retain Ho:there is no realtion between pus_cell_clumps and red_blood_cells
# reject Ho:there is a realtion between pus_cell_clumps and pus_cell
# reject Ho:there is a realtion between pus_cell_clumps and bacteria
# reject Ho:there is a realtion between pus_cell_clumps and hypertension
# reject Ho:there is a realtion between pus_cell_clumps and diabetes_mellitus
# reject Ho:there is a realtion between pus_cell_clumps and coronary_artery_disease
# reject Ho:there is a realtion between pus_cell_clumps and appetite
# retain Ho:there is no realtion between pus_cell_clumps and peda_edema
# reject Ho:there is a realtion between pus_cell_clumps and aanemia
# reject Ho:there is a realtion between pus_cell_clumps and class
# reject Ho:there is a realtion between bacteria and specific_gravity
# reject Ho:there is a realtion between bacteria and albumin
# reject Ho:there is a realtion between bacteria and sugar
# reject Ho:there is a realtion between bacteria and red_blood_cells
# reject Ho:there is a realtion between bacteria and pus_cell
# reject Ho:there is a realtion between bacteria and pus_cell_clumps
# retain Ho:there is no realtion between bacteria and hypertension
# retain Ho:there is no realtion between bacteria and diabetes_mellitus
# reject Ho:there is a realtion between bacteria and coronary_artery_disease
# reject Ho:there is a realtion between bacteria and appetite
# reject Ho:there is a realtion between bacteria and peda_edema
# retain Ho:there is no realtion between bacteria and aanemia
# reject Ho:there is a realtion between bacteria and class
# reject Ho:there is a realtion between hypertension and specific_gravity
# reject Ho:there is a realtion between hypertension and albumin
# reject Ho:there is a realtion between hypertension and sugar
# reject Ho:there is a realtion between hypertension and red_blood_cells
# reject Ho:there is a realtion between hypertension and pus_cell
# reject Ho:there is a realtion between hypertension and pus_cell_clumps
# retain Ho:there is no realtion between hypertension and bacteria
# reject Ho:there is a realtion between hypertension and diabetes_mellitus
# reject Ho:there is a realtion between hypertension and coronary_artery_disease
# reject Ho:there is a realtion between hypertension and appetite
# reject Ho:there is a realtion between hypertension and peda_edema
# reject Ho:there is a realtion between hypertension and aanemia
# reject Ho:there is a realtion between hypertension and class
# reject Ho:there is a realtion between diabetes_mellitus and specific_gravity
# reject Ho:there is a realtion between diabetes_mellitus and albumin
# reject Ho:there is a realtion between diabetes_mellitus and sugar
# reject Ho:there is a realtion between diabetes_mellitus and red_blood_cells
# reject Ho:there is a realtion between diabetes_mellitus and pus_cell
# reject Ho:there is a realtion between diabetes_mellitus and pus_cell_clumps
# retain Ho:there is no realtion between diabetes_mellitus and bacteria
# reject Ho:there is a realtion between diabetes_mellitus and hypertension
# reject Ho:there is a realtion between diabetes_mellitus and coronary_artery_disease
# reject Ho:there is a realtion between diabetes_mellitus and appetite
# reject Ho:there is a realtion between diabetes_mellitus and peda_edema
# reject Ho:there is a realtion between diabetes_mellitus and aanemia
# reject Ho:there is a realtion between diabetes_mellitus and class
# reject Ho:there is a realtion between coronary_artery_disease and specific_gravity
# reject Ho:there is a realtion between coronary_artery_disease and albumin
# reject Ho:there is a realtion between coronary_artery_disease and sugar
# reject Ho:there is a realtion between coronary_artery_disease and red_blood_cells
# reject Ho:there is a realtion between coronary_artery_disease and pus_cell
# reject Ho:there is a realtion between coronary_artery_disease and pus_cell_clumps
# reject Ho:there is a realtion between coronary_artery_disease and bacteria
# reject Ho:there is a realtion between coronary_artery_disease and hypertension
# reject Ho:there is a realtion between coronary_artery_disease and diabetes_mellitus
# reject Ho:there is a realtion between coronary_artery_disease and appetite
# reject Ho:there is a realtion between coronary_artery_disease and peda_edema
# retain Ho:there is no realtion between coronary_artery_disease and aanemia
# reject Ho:there is a realtion between coronary_artery_disease and class
# reject Ho:there is a realtion between appetite and specific_gravity
# reject Ho:there is a realtion between appetite and albumin
# reject Ho:there is a realtion between appetite and sugar
# reject Ho:there is a realtion between appetite and red_blood_cells
# reject Ho:there is a realtion between appetite and pus_cell
# reject Ho:there is a realtion between appetite and pus_cell_clumps
# reject Ho:there is a realtion between appetite and bacteria
# reject Ho:there is a realtion between appetite and hypertension
# reject Ho:there is a realtion between appetite and diabetes_mellitus
# reject Ho:there is a realtion between appetite and coronary_artery_disease
# reject Ho:there is a realtion between appetite and peda_edema
# reject Ho:there is a realtion between appetite and aanemia
# reject Ho:there is a realtion between appetite and class
# reject Ho:there is a realtion between peda_edema and specific_gravity
# reject Ho:there is a realtion between peda_edema and albumin
# reject Ho:there is a realtion between peda_edema and sugar
# reject Ho:there is a realtion between peda_edema and red_blood_cells
# reject Ho:there is a realtion between peda_edema and pus_cell
# retain Ho:there is no realtion between peda_edema and pus_cell_clumps
# reject Ho:there is a realtion between peda_edema and bacteria
# reject Ho:there is a realtion between peda_edema and hypertension
# reject Ho:there is a realtion between peda_edema and diabetes_mellitus
# reject Ho:there is a realtion between peda_edema and coronary_artery_disease
# reject Ho:there is a realtion between peda_edema and appetite
# reject Ho:there is a realtion between peda_edema and aanemia
# reject Ho:there is a realtion between peda_edema and class
# reject Ho:there is a realtion between aanemia and specific_gravity
# reject Ho:there is a realtion between aanemia and albumin
# reject Ho:there is a realtion between aanemia and sugar
# reject Ho:there is a realtion between aanemia and red_blood_cells
# reject Ho:there is a realtion between aanemia and pus_cell
# reject Ho:there is a realtion between aanemia and pus_cell_clumps
# retain Ho:there is no realtion between aanemia and bacteria
# reject Ho:there is a realtion between aanemia and hypertension
# reject Ho:there is a realtion between aanemia and diabetes_mellitus
# retain Ho:there is no realtion between aanemia and coronary_artery_disease
# reject Ho:there is a realtion between aanemia and appetite
# reject Ho:there is a realtion between aanemia and peda_edema
# reject Ho:there is a realtion between aanemia and class
# reject Ho:there is a realtion between class and specific_gravity
# reject Ho:there is a realtion between class and albumin
# reject Ho:there is a realtion between class and sugar
# reject Ho:there is a realtion between class and red_blood_cells
# reject Ho:there is a realtion between class and pus_cell
# reject Ho:there is a realtion between class and pus_cell_clumps
# reject Ho:there is a realtion between class and bacteria
# reject Ho:there is a realtion between class and hypertension
# reject Ho:there is a realtion between class and diabetes_mellitus
# reject Ho:there is a realtion between class and coronary_artery_disease
# reject Ho:there is a realtion between class and appetite
# reject Ho:there is a realtion between class and peda_edema
# reject Ho:there is a realtion between class and aanemia

# %%
# let's check count of null values in whole df
chronic_df.isna().sum ().sort_values(ascending=False)
# Out:
# red_blood_cells            152
# red_blood_cell_count       131
# white_blood_cell_count     106
# potassium                   88
# sodium                      87
# packed_cell_volume          71
# pus_cell                    65
# haemoglobin                 52
# blood_glucose_random        44
# blood_urea                  19
# serum_creatinine            17
# blood_pressure              12
# age                          9
# bacteria                     4
# pus_cell_clumps              4
# hypertension                 2
# diabetes_mellitus            2
# coronary_artery_disease      2
# appetite                     1
# peda_edema                   1
# aanemia                      1
# sugar                        0
# albumin                      0
# specific_gravity             0
# class                        0
# dtype: int64

# %%
# let's check count of null values in num_cols
chronic_df[num_cols].isna().sum ().sort_values(ascending=False)
# Out:
# red_blood_cell_count      131
# white_blood_cell_count    106
# potassium                  88
# sodium                     87
# packed_cell_volume         71
# haemoglobin                52
# blood_glucose_random       44
# blood_urea                 19
# serum_creatinine           17
# blood_pressure             12
# age                         9
# dtype: int64

# %%
# let's check count of null values in cat cols

chronic_df[cat_cols].isna().sum ().sort_values(ascending=False)
# Out:
# red_blood_cells            152
# pus_cell                    65
# pus_cell_clumps              4
# bacteria                     4
# hypertension                 2
# diabetes_mellitus            2
# coronary_artery_disease      2
# appetite                     1
# peda_edema                   1
# aanemia                      1
# specific_gravity             0
# albumin                      0
# sugar                        0
# class                        0
# dtype: int64

# %% [markdown]
# ## **`Missing Value Treatment`**

# %%
# filling null values, we will use two methods, random sampling for higher null values and 
# mean/mode sampling for lower null values

# creating func for imputing random values
def random_value_imputation(feature):
    random_sample =chronic_df[feature].dropna().sample(chronic_df[feature].isna().sum())
    random_sample.index = chronic_df[chronic_df[feature].isna()].index
    chronic_df.loc[chronic_df[feature].isnull(), feature] = random_sample
    
# creating func for imputing most common value(modal value)
def impute_mode(feature):
    mode = chronic_df[feature].mode()[0]
    chronic_df[feature] =chronic_df[feature].fillna(mode)
def impute_mode_fornan(feature):
    mode = chronic_df[feature].mode()[0]
    chronic_df[feature] =np.where(chronic_df[feature]=='nan',mode,chronic_df[feature])

# %%
# filling num_cols null values using random sampling method
for numerical_column in num_cols:
  random_value_imputation(numerical_column)

# %%
# let's check count of null values in num_cols again
chronic_df[num_cols].isna().sum()
# Out:
# age                       0
# blood_pressure            0
# blood_glucose_random      0
# blood_urea                0
# serum_creatinine          0
# sodium                    0
# potassium                 0
# haemoglobin               0
# packed_cell_volume        0
# white_blood_cell_count    0
# red_blood_cell_count      0
# dtype: int64

# %%
# filling "red_blood_cells" and "pus_cell" using random sampling method and rest of cat_cols using mode imputation
random_value_imputation("red_blood_cells")
random_value_imputation("pus_cell")
for col in cat_cols:
  impute_mode(col)
for col in cat_cols:
  impute_mode_fornan(col)

# %%
# let's check count of null values in cat_cols again
chronic_df[cat_cols].isna().sum()
# Out:
# specific_gravity           0
# albumin                    0
# sugar                      0
# red_blood_cells            0
# pus_cell                   0
# pus_cell_clumps            0
# bacteria                   0
# hypertension               0
# diabetes_mellitus          0
# coronary_artery_disease    0
# appetite                   0
# peda_edema                 0
# aanemia                    0
# class                      0
# dtype: int64

# %%
# check unique values in each cat col by looping over cat cols
for column in cat_cols:
  print(f"{column} has {chronic_df[column].nunique()} categories \n")
# Out:
# specific_gravity has 5 categories
#
# albumin has 6 categories
#
# sugar has 6 categories
#
# red_blood_cells has 2 categories
#
# pus_cell has 2 categories
#
# pus_cell_clumps has 2 categories
#
# bacteria has 2 categories
#
# hypertension has 2 categories
#
# diabetes_mellitus has 2 categories
#
# coronary_artery_disease has 2 categories
#
# appetite has 2 categories
#
# peda_edema has 2 categories
#
# aanemia has 2 categories
#
# class has 2 categories

# %%
# using labelencoder and applying on cat cols
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()                 
for col in cat_cols[3:]:
    chronic_df[col] =le.fit_transform(chronic_df[col])

# %%
#converting catgorical on=bjective type into int
chronic_df["specific_gravity"]=chronic_df["specific_gravity"].astype("float")
chronic_df["albumin"]=chronic_df["albumin"].astype("float")
chronic_df["sugar"]=chronic_df["sugar"].astype("float")

# %%
chronic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      400 non-null    float64
#  1   blood_pressure           400 non-null    float64
#  2   specific_gravity         400 non-null    float64
#  3   albumin                  400 non-null    float64
#  4   sugar                    400 non-null    float64
#  5   red_blood_cells          400 non-null    int64
#  6   pus_cell                 400 non-null    int64
#  7   pus_cell_clumps          400 non-null    int64
#  8   bacteria                 400 non-null    int64
#  9   blood_glucose_random     400 non-null    float64
#  10  blood_urea               400 non-null    float64
#  11  serum_creatinine         400 non-null    float64
#  12  sodium                   400 non-null    float64
#  13  potassium                400 non-null    float64
#  14  haemoglobin              400 non-null    float64
#  15  packed_cell_volume       400 non-null    float64
#  16  white_blood_cell_count   400 non-null    float64
#  17  red_blood_cell_count     400 non-null    float64
#  18  hypertension             400 non-null    int64
#  19  diabetes_mellitus        400 non-null    int64
#  20  coronary_artery_disease  400 non-null    int64
#  21  appetite                 400 non-null    int64
#  22  peda_edema               400 non-null    int64
#  23  aanemia                  400 non-null    int64
#  24  class                    400 non-null    int64
# dtypes: float64(14), int64(11)
# memory usage: 78.2 KB

# %%
# check chronic df after transforming cat cols
chronic_df.head()
# Out:
#     age  blood_pressure  specific_gravity  albumin  sugar  red_blood_cells  \
# 0  48.0            80.0             1.020      1.0    0.0                1
# 1   7.0            50.0             1.020      4.0    0.0                1
# 2  62.0            80.0             1.010      2.0    3.0                1
# 3  48.0            70.0             1.005      4.0    0.0                1
# 4  51.0            80.0             1.010      2.0    0.0                1
#
#    pus_cell  pus_cell_clumps  bacteria  blood_glucose_random  ...  \
# 0         1                0         0                 121.0  ...
# 1         1                0         0                 234.0  ...
# 2         1                0         0                 423.0  ...
# 3         0                1         0                 117.0  ...
# 4         1                0         0                 106.0  ...
#
#    packed_cell_volume  white_blood_cell_count  red_blood_cell_count  \
# 0                44.0                  7800.0                   5.2
# 1                38.0                  6000.0                   5.0
# 2                31.0                  7500.0                   5.5
# 3                32.0                  6700.0                   3.9
# 4                35.0                  7300.0                   4.6
#
#    hypertension  diabetes_mellitus  coronary_artery_disease  appetite  \
# 0             1                  1                        0         0
# 1             0                  0                        0         0
# 2             0                  1                        0         1
# 3             1                  0                        0         1
# 4             0                  0                        0         0
#
#    peda_edema  aanemia  class
# 0           0        0      0
# 1           0        0      0
# 2           0        1      0
# 3           1        1      0
# 4           0        0      0
#
# [5 rows x 25 columns]

# %%
# Split data into features and target variables (X and y)
X = chronic_df.iloc[:,:-1]
y = chronic_df.iloc[:,-1]

# %%
# splitting data intp training and test set, so import train_test_split

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=89)

# %% [markdown]
# ## **`Model Building`**

# %%
#defining a function to print accuracy,confusion_matrix,classififcation_report
def get_result(model):
  y_predict=model.predict(X_test)
  y_predict_train=model.predict(X_train)
  print(f"Traning Accuracy of {model} is {accuracy_score(y_train,y_predict_train)}\n")
  print(f"Testin Accuracy of {model} is {accuracy_score(y_test,y_predict)}\n")
  print(f"{confusion_matrix(y_test,y_predict)}\n")
  print(classification_report(y_test,y_predict))
  fpr,tpr,threshold=roc_curve(y_test,y_predict)
  plt.figure(figsize=(18,8))
  plt.plot(fpr,tpr)
  plt.ylabel("tpr")
  plt.xlabel("fpr")
  plt.title("AUC-ROC curve")
  plt.show()

# %%
# import KNeighborsClassifier, accuracy_score, confusion_matrix, classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report,roc_curve

knn = KNeighborsClassifier()

knn.fit(X_train,y_train)

# accuracy score, confusion matrix and classification report of knn
get_result(knn)
# Out:
# Traning Accuracy of KNeighborsClassifier() is 0.8
#
# Testin Accuracy of KNeighborsClassifier() is 0.6916666666666667
#
# [[50 21]
#  [16 33]]
#
#               precision    recall  f1-score   support
#
#            0       0.76      0.70      0.73        71
#            1       0.61      0.67      0.64        49
#
#     accuracy                           0.69       120
#    macro avg       0.68      0.69      0.69       120
# weighted avg       0.70      0.69      0.69       120

# %%
# import DecisionTreeClassifer
from sklearn.tree import DecisionTreeClassifier

dtc =DecisionTreeClassifier()
dtc.fit(X_train,y_train)


# accuracy score, confusion matrix and classification report of decision tree

get_result(dtc)
# Out:
# Traning Accuracy of DecisionTreeClassifier() is 1.0
#
# Testin Accuracy of DecisionTreeClassifier() is 0.9583333333333334
#
# [[70  1]
#  [ 4 45]]
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97        71
#            1       0.98      0.92      0.95        49
#
#     accuracy                           0.96       120
#    macro avg       0.96      0.95      0.96       120
# weighted avg       0.96      0.96      0.96       120

# %%
# hyper parameter tuning of decision tree , import GridSearchCV

from sklearn.model_selection import GridSearchCV

"""
Use this param
 {
    'criterion' : ['gini', 'entropy'],
    'max_depth' : [3, 5, 7, 10],
    'splitter' : ['best', 'random'],
    'min_samples_leaf' : [1, 2, 3, 5, 7],
    'min_samples_split' : [1, 2, 3, 5, 7],
    'max_features' : ['auto', 'sqrt', 'log2']
}

"""

grid_param = {
    'criterion' : ['gini', 'entropy'],
    'max_depth' : [3, 5, 7, 10],
    'splitter' : ['best', 'random'],
    'min_samples_leaf' : [1, 2, 3, 5, 7],
    'min_samples_split' : [1, 2, 3, 5, 7],
    'max_features' : ['auto', 'sqrt', 'log2']
}


# Apply gridsearchcv with cv = 5, n_jobs = -1, verbose = 1
grid_search_dtc = GridSearchCV(
    estimator=dtc,
    param_grid=grid_param,
    scoring="accuracy",
    cv=5,
    n_jobs=-1,
    verbose=1

)
grid_search_dtc.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 1200 candidates, totalling 6000 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 10],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 3, 5, 7],
#                          'min_samples_split': [1, 2, 3, 5, 7],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy', verbose=1)

# %%
# print best parameters and best score in grid search dtc
print(grid_search_dtc.best_params_)
print(grid_search_dtc.best_score_)
# Out:
# {'criterion': 'gini', 'max_depth': 7, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}
# 0.9857142857142858

# %%
# storing best estimator

dtc = DecisionTreeClassifier(**grid_search_dtc.best_params_)
dtc.fit(X_train,y_train)
# accuracy score, confusion matrix and classification report of decision tree

get_result(dtc)
# Out:
# Traning Accuracy of DecisionTreeClassifier(max_depth=7, max_features='sqrt', min_samples_split=5) is 0.9892857142857143
#
# Testin Accuracy of DecisionTreeClassifier(max_depth=7, max_features='sqrt', min_samples_split=5) is 0.95
#
# [[68  3]
#  [ 3 46]]
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        71
#            1       0.94      0.94      0.94        49
#
#     accuracy                           0.95       120
#    macro avg       0.95      0.95      0.95       120
# weighted avg       0.95      0.95      0.95       120

# %%
# import RandomForestClassifier

from sklearn.ensemble import RandomForestClassifier

rd_clf = RandomForestClassifier()
rd_clf.fit(X_train,y_train)
# accuracy score, confusion matrix and classification report of random forest

get_result(rd_clf)
# Out:
# Traning Accuracy of RandomForestClassifier() is 1.0
#
# Testin Accuracy of RandomForestClassifier() is 0.9916666666666667
#
# [[71  0]
#  [ 1 48]]
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        71
#            1       1.00      0.98      0.99        49
#
#     accuracy                           0.99       120
#    macro avg       0.99      0.99      0.99       120
# weighted avg       0.99      0.99      0.99       120

# %%
# import AdaBoostClassifier
from sklearn.ensemble import AdaBoostClassifier
ada =AdaBoostClassifier()
ada.fit(X_train,y_train)
# accuracy score, confusion matrix and classification report of ada boost

get_result(ada)
# Out:
# Traning Accuracy of AdaBoostClassifier() is 1.0
#
# Testin Accuracy of AdaBoostClassifier() is 0.9916666666666667
#
# [[71  0]
#  [ 1 48]]
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        71
#            1       1.00      0.98      0.99        49
#
#     accuracy                           0.99       120
#    macro avg       0.99      0.99      0.99       120
# weighted avg       0.99      0.99      0.99       120

# %%
# import GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier()
gb.fit(X_train,y_train)


# accuracy score, confusion matrix and classification report of gradient boosting classifier

get_result(gb)
# Out:
# Traning Accuracy of GradientBoostingClassifier() is 1.0
#
# Testin Accuracy of GradientBoostingClassifier() is 1.0
#
# [[71  0]
#  [ 0 49]]
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        71
#            1       1.00      1.00      1.00        49
#
#     accuracy                           1.00       120
#    macro avg       1.00      1.00      1.00       120
# weighted avg       1.00      1.00      1.00       120

# %%
# using max_depth = 4, subsample = 0.90, max_features = 0.75, n_estimators = 200
from sklearn.ensemble import GradientBoostingClassifier
sgb = GradientBoostingClassifier(max_depth=4,subsample=0.9,max_features=0.75,n_estimators=200)

sgb.fit(X_train,y_train)


# accuracy score, confusion matrix and classification report of stochastic gradient boosting classifier
get_result(sgb)
# Out:
# Traning Accuracy of GradientBoostingClassifier(max_depth=4, max_features=0.75, n_estimators=200,
#                            subsample=0.9) is 1.0
#
# Testin Accuracy of GradientBoostingClassifier(max_depth=4, max_features=0.75, n_estimators=200,
#                            subsample=0.9) is 0.9916666666666667
#
# [[71  0]
#  [ 1 48]]
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        71
#            1       1.00      0.98      0.99        49
#
#     accuracy                           0.99       120
#    macro avg       0.99      0.99      0.99       120
# weighted avg       0.99      0.99      0.99       120

# %%
# !pip install xgboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xgboost in /usr/local/lib/python3.9/dist-packages (1.7.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from xgboost) (1.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from xgboost) (1.22.4)

# %%
# import XGBClassifier
from xgboost import XGBClassifier

xgb =XGBClassifier(objective="binary:logistic")


# accuracy score, confusion matrix and classification report of xgboost

xgb.fit(X_train,y_train)
get_result(xgb)
# Out:
# Traning Accuracy of XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...) is 1.0
#
# Testin Accuracy of XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...) is 0.9833333333333333
#
# [[71  0]
#  [ 2 47]]
#
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        71
#            1       1.00      0.96      0.98        49
#
#     accuracy                           0.98       120
#    macro avg       0.99      0.98      0.98       120
# weighted avg       0.98      0.98      0.98       120

# %%
# !pip install catboost
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting catboost
#   Downloading catboost-1
# 989:	learn: 0.0096059	total: 2.26s	remaining: 22.8ms
# 990:	learn: 0.0095903	total: 2.26s	remaining: 20.5ms
# 991:	learn: 0.0095715	total: 2.26s	remaining: 18.2ms
# 992:	learn: 0.0095578	total: 2.26s	remaining: 16ms
# 993:	learn: 0.0095420	total: 2.27s	remaining: 13.7ms
# 994:	learn: 0.0095282	total: 2.27s	remaining: 11.4ms
# 995:	learn: 0.0095162	total: 2.27s	remaining: 9.11ms
# 996:	learn: 0.0094986	total: 2.27s	remaining: 6.83ms
# 997:	learn: 0.0094809	total: 2.27s	remaining: 4.56ms
# 998:	learn: 0.0094625	total: 2.28s	remaining: 2.28ms
# 999:	learn: 0.0094442	total: 2.28s	remaining: 0us
# Traning Accuracy of <catboost.core.CatBoostClassifier object at 0x7f3acd7c9ee0> is 1.0
#
# Testin Accuracy of <catboost.core.CatBoostClassifier object at 0x7f3acd7c9ee0> is 0.9833333333333333
#
# [[70  1]
#  [ 1 48]]
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        71
#            1       0.98      0.98      0.98        49
#
#     accuracy                           0.98       120
#    macro avg       0.98      0.98      0.98       120
# weighted avg       0.98      0.98      0.98       120

# %%
# import ExtraTreesClassifier

from sklearn.ensemble import ExtraTreesClassifier

etc = ExtraTreesClassifier()
etc.fit(X_train,y_train)



# accuracy score, confusion matrix and classification report of extra trees classifier

get_result(etc)
# Out:
# Traning Accuracy of ExtraTreesClassifier() is 1.0
#
# Testin Accuracy of ExtraTreesClassifier() is 0.9916666666666667
#
# [[71  0]
#  [ 1 48]]
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        71
#            1       1.00      0.98      0.99        49
#
#     accuracy                           0.99       120
#    macro avg       0.99      0.99      0.99       120
# weighted avg       0.99      0.99      0.99       120

# %%
# import LGBMClassifier
from lightgbm import LGBMClassifier

lgbm = LGBMClassifier()

lgbm.fit(X_train,y_train)


# accuracy score, confusion matrix and classification report of lgbm classifier

get_result(lgbm)
# Out:
# Traning Accuracy of LGBMClassifier() is 1.0
#
# Testin Accuracy of LGBMClassifier() is 0.9916666666666667
#
# [[71  0]
#  [ 1 48]]
#
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        71
#            1       1.00      0.98      0.99        49
#
#     accuracy                           0.99       120
#    macro avg       0.99      0.99      0.99       120
# weighted avg       0.99      0.99      0.99       120

# %%
#geting only accuracy
def getaccuracy(model):
  return accuracy_score(y_test,model.predict(X_test))

# %%
# comparing all models accuracy by creating a df
models = pd.DataFrame({"model":["knn","decisiontree","RandomForest","Adaboost","gradientboost","stochasticgradientboosting","xgboost","catboost","extratreecla","lightgbm"],
                      "score":[getaccuracy(knn),getaccuracy(dtc),getaccuracy(rd_clf),getaccuracy(ada ),getaccuracy(gb),getaccuracy(sgb),getaccuracy(xgb),getaccuracy(cat),getaccuracy(etc),getaccuracy(lgbm)]})

models
# Out:
#                         model     score
# 0                         knn  0.691667
# 1                decisiontree  0.950000
# 2                RandomForest  0.991667
# 3                    Adaboost  0.991667
# 4               gradientboost  1.000000
# 5  stochasticgradientboosting  0.991667
# 6                     xgboost  0.983333
# 7                    catboost  0.983333
# 8                extratreecla  0.991667
# 9                    lightgbm  0.991667
